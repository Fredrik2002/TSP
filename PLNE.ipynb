# %%
import Pkg
Pkg.add("GLPK")
# Out:
#     Updating registry at `C:\Users\calve\.julia\registries\General.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\calve\.julia\environments\v1.9\Project.toml`
#   No Changes to `C:\Users\calve\.julia\environments\v1.9\Manifest.toml`

# %%
using JuMP
using GLPK

function solve_delta_tsp(distances)
    n = size(distances, 1)
    model = Model(GLPK.Optimizer)
    @variable(model, x[1:n, 1:n], Bin)  # Variable binaire pour indiquer si le trajet passe par l'arc (i, j)
    @variable(model, u[1:n])  # Variables de position
    @objective(model, Min, sum(distances[i, j] * x[i, j] for i in 1:n, j in 1:n)) 
    # Contrainte: on ne bloque pas sur la même ville
    @constraint(model, [i in 1:n,], x[i, i] == 0)
    # Contrainte: chaque ville est visitée exactement une fois
    @constraint(model, [i in 1:n], sum(x[i, j] for j in 1:n) == 1)
    @constraint(model, [j in 1:n], sum(x[i, j] for i in 1:n) == 1)
    # Contrainte pour éviter les sous-tours
    @constraint(model, [i=1:n, j=2:n], u[i] - u[j] + n * x[i, j] <= n - 1)
    # Résolution
    optimize!(model)
    if termination_status(model) == MOI.OPTIMAL
        println("Optimal solution found!")
        selected_arcs = value.(x)
        for i in 1:n
            for j in 1:n
                if selected_arcs[i, j] > 0.5
                    println("On voyage de ", i, " vers ", j)
                end
            end
        end
    else
        println("No solution found!")
    end
    println("distance total parcouru ",value.(sum(distances[i, j] * x[i, j] for i in 1:n, j in 1:n)))
end

# Génération aléatoire des coordonnées des villes
using Random
Random.seed!(123)  # Pour la reproductibilité
function calculate_distances(coordonnees)
    nbv = length(coordonnees)
    dist = zeros(nbv, nbv)
    for i in 1:nbv, j in 1:nbv
        dist[i, j] = sqrt((coordonnees[i][1] - coordonnees[j][1])^2 + (coordonnees[i][2] - coordonnees[j][2])^2)
    end
    return dist
end


max_coord = 100  # Plage des coordonnées
N = 16
coordonnees = [(rand(1:max_coord), rand(1:max_coord)) for _ in 1:N]
d = zeros(N, N)
#println(d)
d = calculate_distances(coordonnees)
@time solve_delta_tsp(d)
# Out:
# Optimal solution found!
# On voyage de 1 vers 15
# On voyage de 2 vers 12
# On voyage de 3 vers 5
# On voyage de 4 vers 7
# On voyage de 5 vers 10
# On voyage de 6 vers 11
# On voyage de 7 vers 14
# On voyage de 8 vers 13
# On voyage de 9 vers 1
# On voyage de 10 vers 2
# On voyage de 11 vers 4
# On voyage de 12 vers 9
# On voyage de 13 vers 3
# On voyage de 14 vers 16
# On voyage de 15 vers 6
# On voyage de 16 vers 8
# distance total parcouru 321.74481188754646
#   4.067043 seconds (4.18 M allocations: 285.535 MiB, 5.08% gc time, 97.47% compilation time)

# %%
N = 12

d = [0 1 1 100 100 100;
     1 0 1 100 100 100;
    1 1 0 100 100 100;
100 100 100 0 1 1;
100 100 100 1 0 1;
100 100 100 1 1 0]
@time solve_delta_tsp(d)
# Out:
# Optimal solution found!
# On voyage de 1 vers 3
# On voyage de 2 vers 4
# On voyage de 3 vers 2
# On voyage de 4 vers 5
# On voyage de 5 vers 6
# On voyage de 6 vers 1
# distance total parcouru 204.0
#   0.168370 seconds (160.54 k allocations: 10.845 MiB, 96.66% compilation time)

# %%
function placer(N, distance, solution, score_actuel, meilleure_solution, meilleur_score)
    
    if length(solution)==N
        if score_actuel[1]+distance[solution[1], solution[N]]<meilleur_score[1]
            meilleure_solution[1] = solution
            meilleur_score[1] = score_actuel[1] + distance[solution[1], solution[N]]
        end
    else
        dernier_sommet = solution[length(solution)]
        for i in 1:N
            if (!(i in solution)) && score_actuel[1]+distance[i, dernier_sommet]<meilleur_score[1]
                push!(solution, i)
                placer(N, distance, solution, [score_actuel[1]+distance[i, dernier_sommet]], meilleure_solution, meilleur_score)
                pop!(solution)
            end
        end  
    end
end

function backtracking(N, distance)
        meilleure_solution = [[]]
        placer(N, distance, [1], [0.0], meilleure_solution, [10000000.0])
        println(meilleure_solution)
end
            

N = 14
somme=0
for i in 1:10
    coordonnees = [(rand(1:100), rand(1:100)) for _ in 1:N]
    d = calculate_distances(coordonnees)
    t1 = time()
    @time solve_delta_tsp(d)
    elapsed_time = time()-t1
    println(elapsed_time)
    somme+=elapsed_time
end
println(somme/10)
# Out:
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 12
# On voyage de 3 vers 11
# On voyage de 4 vers 6
# On voyage de 5 vers 1
# On voyage de 6 vers 9
# On voyage de 7 vers 2
# On voyage de 8 vers 4
# On voyage de 9 vers 13
# On voyage de 10 vers 14
# On voyage de 11 vers 7
# On voyage de 12 vers 5
# On voyage de 13 vers 10
# On voyage de 14 vers 3
# distance total parcouru 309.20615229690935
#   1.453448 seconds (52.46 k allocations: 3.786 MiB)
# 1.4539999961853027
# Optimal solution found!
# On voyage de 1 vers 11
# On voyage de 2 vers 7
# On voyage de 3 vers 2
# On voyage de 4 vers 10
# On voyage de 5 vers 6
# On voyage de 6 vers 14
# On voyage de 7 vers 8
# On voyage de 8 vers 1
# On voyage de 9 vers 3
# On voyage de 10 vers 13
# On voyage de 11 vers 4
# On voyage de 12 vers 5
# On voyage de 13 vers 12
# On voyage de 14 vers 9
# distance total parcouru 296.7490727739286
#   1.386460 seconds (43.63 k allocations: 3.661 MiB)
# 1.386000156402588
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 4
# On voyage de 3 vers 1
# On voyage de 4 vers 12
# On voyage de 5 vers 2
# On voyage de 6 vers 9
# On voyage de 7 vers 13
# On voyage de 8 vers 11
# On voyage de 9 vers 5
# On voyage de 10 vers 14
# On voyage de 11 vers 6
# On voyage de 12 vers 3
# On voyage de 13 vers 8
# On voyage de 14 vers 7
# distance total parcouru 348.4346107912214
#   0.147494 seconds (20.72 k allocations: 3.312 MiB)
# 0.14800000190734863
# Optimal solution found!
# On voyage de 1 vers 13
# On voyage de 2 vers 14
# On voyage de 3 vers 9
# On voyage de 4 vers 2
# On voyage de 5 vers 3
# On voyage de 6 vers 1
# On voyage de 7 vers 6
# On voyage de 8 vers 10
# On voyage de 9 vers 7
# On voyage de 10 vers 12
# On voyage de 11 vers 8
# On voyage de 12 vers 4
# On voyage de 13 vers 11
# On voyage de 14 vers 5
# distance total parcouru 242.24346244324084
#   0.462105 seconds (28.80 k allocations: 3.435 MiB)
# 0.46200013160705566
# Optimal solution found!
# On voyage de 1 vers 5
# On voyage de 2 vers 11
# On voyage de 3 vers 8
# On voyage de 4 vers 2
# On voyage de 5 vers 14
# On voyage de 6 vers 1
# On voyage de 7 vers 9
# On voyage de 8 vers 4
# On voyage de 9 vers 3
# On voyage de 10 vers 7
# On voyage de 11 vers 6
# On voyage de 12 vers 10
# On voyage de 13 vers 12
# On voyage de 14 vers 13
# distance total parcouru 354.72790395902473
#   0.943988 seconds (38.07 k allocations: 3.577 MiB)
# 0.9440000057220459
# Optimal solution found!
# On voyage de 1 vers 12
# On voyage de 2 vers 9
# On voyage de 3 vers 11
# On voyage de 4 vers 3
# On voyage de 5 vers 1
# On voyage de 6 vers 10
# On voyage de 7 vers 4
# On voyage de 8 vers 6
# On voyage de 9 vers 13
# On voyage de 10 vers 14
# On voyage de 11 vers 5
# On voyage de 12 vers 8
# On voyage de 13 vers 7
# On voyage de 14 vers 2
# distance total parcouru 350.9248279187427
#  26.122303 seconds (259.59 k allocations: 6.957 MiB)
# 26.122999906539917
# Optimal solution found!
# On voyage de 1 vers 7
# On voyage de 2 vers 5
# On voyage de 3 vers 12
# On voyage de 4 vers 13
# On voyage de 5 vers 10
# On voyage de 6 vers 9
# On voyage de 7 vers 11
# On voyage de 8 vers 2
# On voyage de 9 vers 14
# On voyage de 10 vers 4
# On voyage de 11 vers 8
# On voyage de 12 vers 1
# On voyage de 13 vers 6
# On voyage de 14 vers 3
# distance total parcouru 344.9321758673049
#   0.288772 seconds (25.04 k allocations: 3.378 MiB)
# 0.2890000343322754
# Optimal solution found!
# On voyage de 1 vers 6
# On voyage de 2 vers 4
# On voyage de 3 vers 14
# On voyage de 4 vers 11
# On voyage de 5 vers 2
# On voyage de 6 vers 8
# On voyage de 7 vers 5
# On voyage de 8 vers 3
# On voyage de 9 vers 12
# On voyage de 10 vers 1
# On voyage de 11 vers 10
# On voyage de 12 vers 13
# On voyage de 13 vers 7
# On voyage de 14 vers 9
# distance total parcouru 278.11236026234354
#   4.949921 seconds (100.60 k allocations: 4.531 MiB, 0.76% gc time)
# 4.950000047683716
# Optimal solution found!
# On voyage de 1 vers 7
# On voyage de 2 vers 8
# On voyage de 3 vers 12
# On voyage de 4 vers 14
# On voyage de 5 vers 6
# On voyage de 6 vers 2
# On voyage de 7 vers 5
# On voyage de 8 vers 10
# On voyage de 9 vers 4
# On voyage de 10 vers 11
# On voyage de 11 vers 9
# On voyage de 12 vers 13
# On voyage de 13 vers 1
# On voyage de 14 vers 3
# distance total parcouru 318.804727444761
#   0.038572 seconds (17.48 k allocations: 3.251 MiB)
# 0.037999868392944336
# Optimal solution found!
# On voyage de 1 vers 11
# On voyage de 2 vers 5
# On voyage de 3 vers 4
# On voyage de 4 vers 8
# On voyage de 5 vers 3
# On voyage de 6 vers 14
# On voyage de 7 vers 12
# On voyage de 8 vers 1
# On voyage de 9 vers 7
# On voyage de 10 vers 6
# On voyage de 11 vers 9
# On voyage de 12 vers 10
# On voyage de 13 vers 2
# On voyage de 14 vers 13
# distance total parcouru 331.0975530108355
#   0.093610 seconds (19.02 k allocations: 3.289 MiB)
# 0.09500002861022949
# 3.588900017738342

# %%
using DelimitedFiles

M = readdlm("main1/instances.txt")
m, N = size(M)
k = Integer(m/N)
fichier_entree = open("main1/datas_exacte.csv", "r")
lignes = readlines(fichier_entree)
close(fichier_entree)


for i in 1:k
    d=M[(i-1)*N+1:i*N,:]
    
    t1 = time()
    solve_delta_tsp(d)
    elapsed_time = time()-t1
    
    lignes[i+2]*=string(round(elapsed_time, digits=3))
    println(lignes[i+2])
end

fichier_sortie = open("main1/datas_exacte.csv", "w")
write(fichier_sortie, join(lignes, "\n"))
close(fichier_sortie)
# Out:
# Optimal solution found!
# On voyage de 1 vers 2
# On voyage de 2 vers 9
# On voyage de 3 vers 5
# On voyage de 4 vers 3
# On voyage de 5 vers 7
# On voyage de 6 vers 4
# On voyage de 7 vers 10
# On voyage de 8 vers 6
# On voyage de 9 vers 8
# On voyage de 10 vers 1
# distance total parcouru 362.0
# 1.917,0.144,21,0.382,109,0.001,0.031
# Optimal solution found!
# On voyage de 1 vers 5
# On voyage de 2 vers 10
# On voyage de 3 vers 9
# On voyage de 4 vers 2
# On voyage de 5 vers 7
# On voyage de 6 vers 8
# On voyage de 7 vers 4
# On voyage de 8 vers 1
# On voyage de 9 vers 6
# On voyage de 10 vers 3
# distance total parcouru 410.0
# 2.925,2.675,309,0.768,199,0,0.033
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 10
# On voyage de 3 vers 5
# On voyage de 4 vers 2
# On voyage de 5 vers 1
# On voyage de 6 vers 4
# On voyage de 7 vers 6
# On voyage de 8 vers 7
# On voyage de 9 vers 3
# On voyage de 10 vers 9
# distance total parcouru 354.0
# 4.679,31.514,1831,1.945,952,0,0.048
# Optimal solution found!
# On voyage de 1 vers 3
# On voyage de 2 vers 6
# On voyage de 3 vers 7
# On voyage de 4 vers 9
# On voyage de 5 vers 2
# On voyage de 6 vers 10
# On voyage de 7 vers 8
# On voyage de 8 vers 5
# On voyage de 9 vers 1
# On voyage de 10 vers 4
# distance total parcouru 426.0
# 4.172,1.118,173,0.416,190,0,0.019
# Optimal solution found!
# On voyage de 1 vers 6
# On voyage de 2 vers 4
# On voyage de 3 vers 8
# On voyage de 4 vers 7
# On voyage de 5 vers 3
# On voyage de 6 vers 5
# On voyage de 7 vers 9
# On voyage de 8 vers 2
# On voyage de 9 vers 10
# On voyage de 10 vers 1
# distance total parcouru 366.0
# 5.447,23.272,1734,2.407,1279,0,0.166
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 5
# On voyage de 3 vers 4
# On voyage de 4 vers 2
# On voyage de 5 vers 7
# On voyage de 6 vers 9
# On voyage de 7 vers 1
# On voyage de 8 vers 6
# On voyage de 9 vers 10
# On voyage de 10 vers 3
# distance total parcouru 348.0
# 2.982,14.243,1270,5.117,1916,0,0.075
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 10
# On voyage de 3 vers 2
# On voyage de 4 vers 3
# On voyage de 5 vers 6
# On voyage de 6 vers 4
# On voyage de 7 vers 1
# On voyage de 8 vers 5
# On voyage de 9 vers 7
# On voyage de 10 vers 9
# distance total parcouru 396.0
# 5.456,9.86,727,1.141,507,0,0.031
# Optimal solution found!
# On voyage de 1 vers 3
# On voyage de 2 vers 5
# On voyage de 3 vers 7
# On voyage de 4 vers 8
# On voyage de 5 vers 1
# On voyage de 6 vers 10
# On voyage de 7 vers 4
# On voyage de 8 vers 6
# On voyage de 9 vers 2
# On voyage de 10 vers 9
# distance total parcouru 342.0
# 2.61,0.749,106,0.343,78,0,0.011
# Optimal solution found!
# On voyage de 1 vers 6
# On voyage de 2 vers 10
# On voyage de 3 vers 5
# On voyage de 4 vers 9
# On voyage de 5 vers 2
# On voyage de 6 vers 7
# On voyage de 7 vers 4
# On voyage de 8 vers 1
# On voyage de 9 vers 3
# On voyage de 10 vers 8
# distance total parcouru 422.0
# 4.167,1.509,230,0.715,370,0,0.068
# Optimal solution found!
# On voyage de 1 vers 4
# On voyage de 2 vers 10
# On voyage de 3 vers 7
# On voyage de 4 vers 2
# On voyage de 5 vers 1
# On voyage de 6 vers 8
# On voyage de 7 vers 6
# On voyage de 8 vers 5
# On voyage de 9 vers 3
# On voyage de 10 vers 9
# distance total parcouru 324.0
# 1.199,1.774,268,1.334,527,0,0.035
# Optimal solution found!
# On voyage de 1 vers 3
# On voyage de 2 vers 6
# On voyage de 3 vers 10
# On voyage de 4 vers 9
# On voyage de 5 vers 7
# On voyage de 6 vers 1
# On voyage de 7 vers 2
# On voyage de 8 vers 4
# On voyage de 9 vers 5
# On voyage de 10 vers 8
# distance total parcouru 360.0
# 2.115,0.018,2,0.121,58,0,0.009
# Optimal solution found!
# On voyage de 1 vers 5
# On voyage de 2 vers 10
# On voyage de 3 vers 7
# On voyage de 4 vers 6
# On voyage de 5 vers 9
# On voyage de 6 vers 3
# On voyage de 7 vers 2
# On voyage de 8 vers 4
# On voyage de 9 vers 8
# On voyage de 10 vers 1
# distance total parcouru 406.0
# 3.58,0.36,33,0.38,90,0,0.07
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 7
# On voyage de 3 vers 5
# On voyage de 4 vers 3
# On voyage de 5 vers 9
# On voyage de 6 vers 4
# On voyage de 7 vers 1
# On voyage de 8 vers 2
# On voyage de 9 vers 8
# On voyage de 10 vers 6
# distance total parcouru 338.0
# 2.984,1.07,166,0.644,270,0,0.033
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 6
# On voyage de 3 vers 4
# On voyage de 4 vers 7
# On voyage de 5 vers 1
# On voyage de 6 vers 3
# On voyage de 7 vers 5
# On voyage de 8 vers 2
# On voyage de 9 vers 8
# On voyage de 10 vers 9
# distance total parcouru 276.0
# 4.432,38.346,2074,1.546,697,0,0.067
# Optimal solution found!
# On voyage de 1 vers 5
# On voyage de 2 vers 4
# On voyage de 3 vers 7
# On voyage de 4 vers 9
# On voyage de 5 vers 10
# On voyage de 6 vers 3
# On voyage de 7 vers 8
# On voyage de 8 vers 2
# On voyage de 9 vers 1
# On voyage de 10 vers 6
# distance total parcouru 364.0
# 5.368,0.044,4,0.547,278,0.001,0.008
# Optimal solution found!
# On voyage de 1 vers 9
# On voyage de 2 vers 5
# On voyage de 3 vers 7
# On voyage de 4 vers 8
# On voyage de 5 vers 6
# On voyage de 6 vers 10
# On voyage de 7 vers 4
# On voyage de 8 vers 1
# On voyage de 9 vers 2
# On voyage de 10 vers 3
# distance total parcouru 370.0
# 3.341,181.862,5501,2.483,1263,0,0.149
# Optimal solution found!
# On voyage de 1 vers 9
# On voyage de 2 vers 4
# On voyage de 3 vers 6
# On voyage de 4 vers 8
# On voyage de 5 vers 2
# On voyage de 6 vers 7
# On voyage de 7 vers 5
# On voyage de 8 vers 1
# On voyage de 9 vers 10
# On voyage de 10 vers 3
# distance total parcouru 364.0
# 2.782,1.5,217,0.371,155,0.001,0.058
# Optimal solution found!
# On voyage de 1 vers 3
# On voyage de 2 vers 10
# On voyage de 3 vers 8
# On voyage de 4 vers 7
# On voyage de 5 vers 1
# On voyage de 6 vers 5
# On voyage de 7 vers 9
# On voyage de 8 vers 4
# On voyage de 9 vers 2
# On voyage de 10 vers 6
# distance total parcouru 328.0
# 3.047,3.105,387,1.447,822,0.001,0.06
# Optimal solution found!
# On voyage de 1 vers 2
# On voyage de 2 vers 9
# On voyage de 3 vers 10
# On voyage de 4 vers 5
# On voyage de 5 vers 1
# On voyage de 6 vers 4
# On voyage de 7 vers 8
# On voyage de 8 vers 6
# On voyage de 9 vers 3
# On voyage de 10 vers 7
# distance total parcouru 350.0
# 1.719,0.654,104,0.524,192,0,0.035
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 8
# On voyage de 3 vers 7
# On voyage de 4 vers 1
# On voyage de 5 vers 9
# On voyage de 6 vers 5
# On voyage de 7 vers 2
# On voyage de 8 vers 4
# On voyage de 9 vers 3
# On voyage de 10 vers 6
# distance total parcouru 276.0
# 3.446,0.951,143,11.025,5314,0,0.154
# Optimal solution found!
# On voyage de 1 vers 9
# On voyage de 2 vers 7
# On voyage de 3 vers 2
# On voyage de 4 vers 3
# On voyage de 5 vers 4
# On voyage de 6 vers 8
# On voyage de 7 vers 6
# On voyage de 8 vers 1
# On voyage de 9 vers 10
# On voyage de 10 vers 5
# distance total parcouru 356.0
# 6.485,0.311,46,1.557,878,0,0.017
# Optimal solution found!
# On voyage de 1 vers 6
# On voyage de 2 vers 7
# On voyage de 3 vers 4
# On voyage de 4 vers 1
# On voyage de 5 vers 8
# On voyage de 6 vers 2
# On voyage de 7 vers 5
# On voyage de 8 vers 9
# On voyage de 9 vers 10
# On voyage de 10 vers 3
# distance total parcouru 352.0
# 2.196,0.25,18,0.415,152,0,0.09
# Optimal solution found!
# On voyage de 1 vers 7
# On voyage de 2 vers 6
# On voyage de 3 vers 2
# On voyage de 4 vers 3
# On voyage de 5 vers 4
# On voyage de 6 vers 10
# On voyage de 7 vers 5
# On voyage de 8 vers 1
# On voyage de 9 vers 8
# On voyage de 10 vers 9
# distance total parcouru 360.0
# 2.442,0.248,40,0.408,172,0,0.013
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 6
# On voyage de 3 vers 5
# On voyage de 4 vers 2
# On voyage de 5 vers 4
# On voyage de 6 vers 8
# On voyage de 7 vers 3
# On voyage de 8 vers 1
# On voyage de 9 vers 7
# On voyage de 10 vers 9
# distance total parcouru 384.0
# 4.577,18.928,1596,2.711,1611,0.001,0.104
# Optimal solution found!
# On voyage de 1 vers 5
# On voyage de 2 vers 6
# On voyage de 3 vers 10
# On voyage de 4 vers 7
# On voyage de 5 vers 2
# On voyage de 6 vers 4
# On voyage de 7 vers 8
# On voyage de 8 vers 9
# On voyage de 9 vers 3
# On voyage de 10 vers 1
# distance total parcouru 332.0
# 2.879,0.524,76,0.837,218,0,0.014
# Optimal solution found!
# On voyage de 1 vers 7
# On voyage de 2 vers 6
# On voyage de 3 vers 8
# On voyage de 4 vers 5
# On voyage de 5 vers 3
# On voyage de 6 vers 9
# On voyage de 7 vers 4
# On voyage de 8 vers 10
# On voyage de 9 vers 1
# On voyage de 10 vers 2
# distance total parcouru 356.0
# 1.965,0.066,12,0.177,44,0.001,0.025
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 7
# On voyage de 3 vers 4
# On voyage de 4 vers 2
# On voyage de 5 vers 9
# On voyage de 6 vers 8
# On voyage de 7 vers 5
# On voyage de 8 vers 3
# On voyage de 9 vers 1
# On voyage de 10 vers 6
# distance total parcouru 348.0
# 3.418,10.577,1053,3.737,1710,0,0.028
# Optimal solution found!
# On voyage de 1 vers 4
# On voyage de 2 vers 10
# On voyage de 3 vers 5
# On voyage de 4 vers 9
# On voyage de 5 vers 6
# On voyage de 6 vers 8
# On voyage de 7 vers 2
# On voyage de 8 vers 1
# On voyage de 9 vers 7
# On voyage de 10 vers 3
# distance total parcouru 372.0
# 1.877,0.076,10,0.346,143,0,0.042
# Optimal solution found!
# On voyage de 1 vers 7
# On voyage de 2 vers 10
# On voyage de 3 vers 2
# On voyage de 4 vers 1
# On voyage de 5 vers 6
# On voyage de 6 vers 8
# On voyage de 7 vers 5
# On voyage de 8 vers 3
# On voyage de 9 vers 4
# On voyage de 10 vers 9
# distance total parcouru 406.0
# 3.914,126.169,5439,2.058,1047,0,0.048
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 4
# On voyage de 3 vers 6
# On voyage de 4 vers 3
# On voyage de 5 vers 2
# On voyage de 6 vers 7
# On voyage de 7 vers 9
# On voyage de 8 vers 5
# On voyage de 9 vers 1
# On voyage de 10 vers 8
# distance total parcouru 338.0
# 2.557,0.195,24,0.682,116,0,0.014
# Optimal solution found!
# On voyage de 1 vers 9
# On voyage de 2 vers 3
# On voyage de 3 vers 10
# On voyage de 4 vers 2
# On voyage de 5 vers 1
# On voyage de 6 vers 8
# On voyage de 7 vers 6
# On voyage de 8 vers 5
# On voyage de 9 vers 4
# On voyage de 10 vers 7
# distance total parcouru 342.0
# 2.682,173.884,6763,6.653,2188,0.001,0.416
# Optimal solution found!
# On voyage de 1 vers 4
# On voyage de 2 vers 8
# On voyage de 3 vers 2
# On voyage de 4 vers 10
# On voyage de 5 vers 6
# On voyage de 6 vers 3
# On voyage de 7 vers 1
# On voyage de 8 vers 7
# On voyage de 9 vers 5
# On voyage de 10 vers 9
# distance total parcouru 396.0
# 3.26,13.161,1197,1.263,515,0,0.02
# Optimal solution found!
# On voyage de 1 vers 9
# On voyage de 2 vers 8
# On voyage de 3 vers 10
# On voyage de 4 vers 6
# On voyage de 5 vers 3
# On voyage de 6 vers 1
# On voyage de 7 vers 4
# On voyage de 8 vers 5
# On voyage de 9 vers 2
# On voyage de 10 vers 7
# distance total parcouru 372.0
# 4.768,515.873,9470,5.875,2528,0,0.394
# Optimal solution found!
# On voyage de 1 vers 9
# On voyage de 2 vers 4
# On voyage de 3 vers 10
# On voyage de 4 vers 6
# On voyage de 5 vers 2
# On voyage de 6 vers 8
# On voyage de 7 vers 1
# On voyage de 8 vers 7
# On voyage de 9 vers 3
# On voyage de 10 vers 5
# distance total parcouru 350.0
# 5.084,1.316,140,0.847,354,0,0.012
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 3
# On voyage de 3 vers 1
# On voyage de 4 vers 5
# On voyage de 5 vers 2
# On voyage de 6 vers 10
# On voyage de 7 vers 9
# On voyage de 8 vers 7
# On voyage de 9 vers 6
# On voyage de 10 vers 4
# distance total parcouru 390.0
# 2.731,14.848,1320,1.646,755,0,0.138
# Optimal solution found!
# On voyage de 1 vers 4
# On voyage de 2 vers 1
# On voyage de 3 vers 6
# On voyage de 4 vers 7
# On voyage de 5 vers 10
# On voyage de 6 vers 9
# On voyage de 7 vers 3
# On voyage de 8 vers 2
# On voyage de 9 vers 5
# On voyage de 10 vers 8
# distance total parcouru 370.0
# 1.973,8.626,942,2.959,1330,0,0.098
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 4
# On voyage de 3 vers 9
# On voyage de 4 vers 1
# On voyage de 5 vers 10
# On voyage de 6 vers 2
# On voyage de 7 vers 3
# On voyage de 8 vers 5
# On voyage de 9 vers 6
# On voyage de 10 vers 7
# distance total parcouru 358.0
# 2.425,6.116,738,3.771,1672,0,0.089
# Optimal solution found!
# On voyage de 1 vers 9
# On voyage de 2 vers 1
# On voyage de 3 vers 2
# On voyage de 4 vers 6
# On voyage de 5 vers 7
# On voyage de 6 vers 3
# On voyage de 7 vers 10
# On voyage de 8 vers 5
# On voyage de 9 vers 8
# On voyage de 10 vers 4
# distance total parcouru 396.0
# 2.846,0.389,44,0.424,125,0,0.011
# Optimal solution found!
# On voyage de 1 vers 5
# On voyage de 2 vers 10
# On voyage de 3 vers 8
# On voyage de 4 vers 7
# On voyage de 5 vers 2
# On voyage de 6 vers 4
# On voyage de 7 vers 3
# On voyage de 8 vers 1
# On voyage de 9 vers 6
# On voyage de 10 vers 9
# distance total parcouru 344.0
# 1.807,1.052,175,0.727,303,0,0.058
# Optimal solution found!
# On voyage de 1 vers 2
# On voyage de 2 vers 10
# On voyage de 3 vers 4
# On voyage de 4 vers 8
# On voyage de 5 vers 9
# On voyage de 6 vers 7
# On voyage de 7 vers 1
# On voyage de 8 vers 5
# On voyage de 9 vers 6
# On voyage de 10 vers 3
# distance total parcouru 362.0
# 2.053,9.67,804,3.166,1736,0,0.045
# Optimal solution found!
# On voyage de 1 vers 7
# On voyage de 2 vers 1
# On voyage de 3 vers 8
# On voyage de 4 vers 10
# On voyage de 5 vers 9
# On voyage de 6 vers 5
# On voyage de 7 vers 4
# On voyage de 8 vers 2
# On voyage de 9 vers 3
# On voyage de 10 vers 6
# distance total parcouru 354.0
# 2.656,0.149,22,0.26,109,0,0.014
# Optimal solution found!
# On voyage de 1 vers 4
# On voyage de 2 vers 10
# On voyage de 3 vers 6
# On voyage de 4 vers 5
# On voyage de 5 vers 8
# On voyage de 6 vers 7
# On voyage de 7 vers 1
# On voyage de 8 vers 9
# On voyage de 9 vers 2
# On voyage de 10 vers 3
# distance total parcouru 360.0
# 2.002,0.505,92,0.18,52,0.001,0.024
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 1
# On voyage de 3 vers 4
# On voyage de 4 vers 8
# On voyage de 5 vers 2
# On voyage de 6 vers 7
# On voyage de 7 vers 3
# On voyage de 8 vers 5
# On voyage de 9 vers 6
# On voyage de 10 vers 9
# distance total parcouru 322.0
# 2.95,37.693,1544,2.114,680,0,0.141
# Optimal solution found!
# On voyage de 1 vers 2
# On voyage de 2 vers 9
# On voyage de 3 vers 1
# On voyage de 4 vers 6
# On voyage de 5 vers 4
# On voyage de 6 vers 7
# On voyage de 7 vers 10
# On voyage de 8 vers 5
# On voyage de 9 vers 8
# On voyage de 10 vers 3
# distance total parcouru 368.0
# 3.649,3.892,491,2.519,1447,0,0.073
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 3
# On voyage de 3 vers 5
# On voyage de 4 vers 7
# On voyage de 5 vers 9
# On voyage de 6 vers 1
# On voyage de 7 vers 8
# On voyage de 8 vers 6
# On voyage de 9 vers 4
# On voyage de 10 vers 2
# distance total parcouru 388.0
# 1.718,0.773,114,0.96,239,0.001,0.022
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 8
# On voyage de 3 vers 5
# On voyage de 4 vers 6
# On voyage de 5 vers 7
# On voyage de 6 vers 1
# On voyage de 7 vers 9
# On voyage de 8 vers 4
# On voyage de 9 vers 2
# On voyage de 10 vers 3
# distance total parcouru 354.0
# 2.294,4.02,550,3.532,1567,0,0.112
# Optimal solution found!
# On voyage de 1 vers 2
# On voyage de 2 vers 10
# On voyage de 3 vers 5
# On voyage de 4 vers 9
# On voyage de 5 vers 6
# On voyage de 6 vers 7
# On voyage de 7 vers 4
# On voyage de 8 vers 1
# On voyage de 9 vers 8
# On voyage de 10 vers 3
# distance total parcouru 308.0
# 1.201,0.497,86,0.398,190,0,0.025
# Optimal solution found!
# On voyage de 1 vers 5
# On voyage de 2 vers 7
# On voyage de 3 vers 2
# On voyage de 4 vers 8
# On voyage de 5 vers 9
# On voyage de 6 vers 3
# On voyage de 7 vers 10
# On voyage de 8 vers 1
# On voyage de 9 vers 6
# On voyage de 10 vers 4
# distance total parcouru 352.0
# 3.244,16.448,1121,1.691,642,0,0.062
# Optimal solution found!
# On voyage de 1 vers 5
# On voyage de 2 vers 3
# On voyage de 3 vers 9
# On voyage de 4 vers 10
# On voyage de 5 vers 2
# On voyage de 6 vers 4
# On voyage de 7 vers 8
# On voyage de 8 vers 1
# On voyage de 9 vers 6
# On voyage de 10 vers 7
# distance total parcouru 316.0
# 2.45,0.023,3,0.106,33,0,0.011
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 9
# On voyage de 3 vers 1
# On voyage de 4 vers 7
# On voyage de 5 vers 10
# On voyage de 6 vers 5
# On voyage de 7 vers 2
# On voyage de 8 vers 6
# On voyage de 9 vers 3
# On voyage de 10 vers 4
# distance total parcouru 300.0
# 4.208,3.217,385,4.764,2105,0,0.048
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 9
# On voyage de 3 vers 2
# On voyage de 4 vers 10
# On voyage de 5 vers 6
# On voyage de 6 vers 1
# On voyage de 7 vers 3
# On voyage de 8 vers 4
# On voyage de 9 vers 5
# On voyage de 10 vers 7
# distance total parcouru 382.0
# 1.519,0.162,14,1.043,477,0,0.027
# Optimal solution found!
# On voyage de 1 vers 3
# On voyage de 2 vers 5
# On voyage de 3 vers 10
# On voyage de 4 vers 9
# On voyage de 5 vers 8
# On voyage de 6 vers 7
# On voyage de 7 vers 2
# On voyage de 8 vers 4
# On voyage de 9 vers 1
# On voyage de 10 vers 6
# distance total parcouru 368.0
# 1.708,0.055,9,0.261,149,0,0.047
# Optimal solution found!
# On voyage de 1 vers 5
# On voyage de 2 vers 1
# On voyage de 3 vers 7
# On voyage de 4 vers 2
# On voyage de 5 vers 8
# On voyage de 6 vers 10
# On voyage de 7 vers 4
# On voyage de 8 vers 6
# On voyage de 9 vers 3
# On voyage de 10 vers 9
# distance total parcouru 438.0
# 3.443,1.323,144,0.434,111,0.001,0.014
# Optimal solution found!
# On voyage de 1 vers 7
# On voyage de 2 vers 5
# On voyage de 3 vers 9
# On voyage de 4 vers 8
# On voyage de 5 vers 1
# On voyage de 6 vers 4
# On voyage de 7 vers 10
# On voyage de 8 vers 2
# On voyage de 9 vers 6
# On voyage de 10 vers 3
# distance total parcouru 292.0
# 5.164,1086.61,13873,11.012,3772,0,0.029
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 3
# On voyage de 3 vers 6
# On voyage de 4 vers 7
# On voyage de 5 vers 9
# On voyage de 6 vers 8
# On voyage de 7 vers 1
# On voyage de 8 vers 5
# On voyage de 9 vers 4
# On voyage de 10 vers 2
# distance total parcouru 318.0
# 4.094,0.958,88,1.013,279,0,0.036
# Optimal solution found!
# On voyage de 1 vers 5
# On voyage de 2 vers 3
# On voyage de 3 vers 10
# On voyage de 4 vers 9
# On voyage de 5 vers 6
# On voyage de 6 vers 2
# On voyage de 7 vers 4
# On voyage de 8 vers 1
# On voyage de 9 vers 8
# On voyage de 10 vers 7
# distance total parcouru 338.0
# 1.574,0.016,2,0.122,28,0,0.011
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 6
# On voyage de 3 vers 8
# On voyage de 4 vers 2
# On voyage de 5 vers 1
# On voyage de 6 vers 9
# On voyage de 7 vers 4
# On voyage de 8 vers 5
# On voyage de 9 vers 3
# On voyage de 10 vers 7
# distance total parcouru 382.0
# 5.53,65.88,2573,1.488,514,0,0.014
# Optimal solution found!
# On voyage de 1 vers 6
# On voyage de 2 vers 4
# On voyage de 3 vers 5
# On voyage de 4 vers 9
# On voyage de 5 vers 10
# On voyage de 6 vers 2
# On voyage de 7 vers 1
# On voyage de 8 vers 3
# On voyage de 9 vers 8
# On voyage de 10 vers 7
# distance total parcouru 286.0
# 2.676,34.105,2400,9.009,4120,0,0.315
# Optimal solution found!
# On voyage de 1 vers 7
# On voyage de 2 vers 3
# On voyage de 3 vers 1
# On voyage de 4 vers 5
# On voyage de 5 vers 2
# On voyage de 6 vers 8
# On voyage de 7 vers 10
# On voyage de 8 vers 9
# On voyage de 9 vers 4
# On voyage de 10 vers 6
# distance total parcouru 372.0
# 3.116,2.876,320,1.121,479,0,0.02
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 4
# On voyage de 3 vers 2
# On voyage de 4 vers 7
# On voyage de 5 vers 3
# On voyage de 6 vers 9
# On voyage de 7 vers 6
# On voyage de 8 vers 5
# On voyage de 9 vers 1
# On voyage de 10 vers 8
# distance total parcouru 290.0
# 4.776,0.457,74,0.465,197,0,0.014
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 1
# On voyage de 3 vers 6
# On voyage de 4 vers 2
# On voyage de 5 vers 3
# On voyage de 6 vers 7
# On voyage de 7 vers 9
# On voyage de 8 vers 10
# On voyage de 9 vers 4
# On voyage de 10 vers 5
# distance total parcouru 370.0
# 2.687,8.34,869,1.194,478,0,0.014
# Optimal solution found!
# On voyage de 1 vers 2
# On voyage de 2 vers 6
# On voyage de 3 vers 1
# On voyage de 4 vers 3
# On voyage de 5 vers 7
# On voyage de 6 vers 9
# On voyage de 7 vers 4
# On voyage de 8 vers 10
# On voyage de 9 vers 8
# On voyage de 10 vers 5
# distance total parcouru 346.0
# 3.568,22.47,1366,2.961,1491,0,0.305
# Optimal solution found!
# On voyage de 1 vers 4
# On voyage de 2 vers 7
# On voyage de 3 vers 9
# On voyage de 4 vers 8
# On voyage de 5 vers 2
# On voyage de 6 vers 10
# On voyage de 7 vers 3
# On voyage de 8 vers 6
# On voyage de 9 vers 1
# On voyage de 10 vers 5
# distance total parcouru 380.0
# 2.436,0.044,3,0.117,30,0,0.017
# Optimal solution found!
# On voyage de 1 vers 4
# On voyage de 2 vers 1
# On voyage de 3 vers 9
# On voyage de 4 vers 7
# On voyage de 5 vers 3
# On voyage de 6 vers 8
# On voyage de 7 vers 5
# On voyage de 8 vers 2
# On voyage de 9 vers 10
# On voyage de 10 vers 6
# distance total parcouru 382.0
# 5.592,4.489,534,3.179,1578,0,0.024
# Optimal solution found!
# On voyage de 1 vers 3
# On voyage de 2 vers 7
# On voyage de 3 vers 4
# On voyage de 4 vers 2
# On voyage de 5 vers 6
# On voyage de 6 vers 8
# On voyage de 7 vers 9
# On voyage de 8 vers 1
# On voyage de 9 vers 10
# On voyage de 10 vers 5
# distance total parcouru 356.0
# 2.161,2.669,388,0.708,357,0,0.037
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 7
# On voyage de 3 vers 1
# On voyage de 4 vers 3
# On voyage de 5 vers 10
# On voyage de 6 vers 9
# On voyage de 7 vers 5
# On voyage de 8 vers 2
# On voyage de 9 vers 4
# On voyage de 10 vers 6
# distance total parcouru 294.0
# 1.752,0.288,46,0.121,32,0,0.024
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 9
# On voyage de 3 vers 2
# On voyage de 4 vers 7
# On voyage de 5 vers 1
# On voyage de 6 vers 8
# On voyage de 7 vers 5
# On voyage de 8 vers 4
# On voyage de 9 vers 6
# On voyage de 10 vers 3
# distance total parcouru 328.0
# 3.364,3.257,325,1.312,389,0,0.025
# Optimal solution found!
# On voyage de 1 vers 5
# On voyage de 2 vers 9
# On voyage de 3 vers 1
# On voyage de 4 vers 6
# On voyage de 5 vers 4
# On voyage de 6 vers 7
# On voyage de 7 vers 8
# On voyage de 8 vers 10
# On voyage de 9 vers 3
# On voyage de 10 vers 2
# distance total parcouru 268.0
# 2.101,16.491,1438,5.339,2166,0,0.144
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 3
# On voyage de 3 vers 1
# On voyage de 4 vers 7
# On voyage de 5 vers 8
# On voyage de 6 vers 9
# On voyage de 7 vers 5
# On voyage de 8 vers 6
# On voyage de 9 vers 2
# On voyage de 10 vers 4
# distance total parcouru 378.0
# 3.835,3.712,457,0.775,320,0,0.041
# Optimal solution found!
# On voyage de 1 vers 2
# On voyage de 2 vers 10
# On voyage de 3 vers 8
# On voyage de 4 vers 5
# On voyage de 5 vers 6
# On voyage de 6 vers 1
# On voyage de 7 vers 3
# On voyage de 8 vers 9
# On voyage de 9 vers 4
# On voyage de 10 vers 7
# distance total parcouru 384.0
# 5.485,421.387,9503,6.63,2732,0,0.013
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 6
# On voyage de 3 vers 5
# On voyage de 4 vers 1
# On voyage de 5 vers 7
# On voyage de 6 vers 4
# On voyage de 7 vers 10
# On voyage de 8 vers 9
# On voyage de 9 vers 3
# On voyage de 10 vers 2
# distance total parcouru 350.0
# 5.077,153.984,4972,4.064,1745,0,0.034
# Optimal solution found!
# On voyage de 1 vers 4
# On voyage de 2 vers 3
# On voyage de 3 vers 10
# On voyage de 4 vers 9
# On voyage de 5 vers 6
# On voyage de 6 vers 2
# On voyage de 7 vers 5
# On voyage de 8 vers 1
# On voyage de 9 vers 7
# On voyage de 10 vers 8
# distance total parcouru 380.0
# 3.668,0.999,156,0.269,101,0,0.03
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 9
# On voyage de 3 vers 7
# On voyage de 4 vers 1
# On voyage de 5 vers 10
# On voyage de 6 vers 5
# On voyage de 7 vers 6
# On voyage de 8 vers 2
# On voyage de 9 vers 3
# On voyage de 10 vers 4
# distance total parcouru 390.0
# 2.404,2.234,316,1.197,507,0,0.042
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 4
# On voyage de 3 vers 10
# On voyage de 4 vers 7
# On voyage de 5 vers 2
# On voyage de 6 vers 3
# On voyage de 7 vers 1
# On voyage de 8 vers 9
# On voyage de 9 vers 6
# On voyage de 10 vers 5
# distance total parcouru 270.0
# 3.201,3.256,429,1.614,944,0,0.065
# Optimal solution found!
# On voyage de 1 vers 5
# On voyage de 2 vers 10
# On voyage de 3 vers 1
# On voyage de 4 vers 9
# On voyage de 5 vers 7
# On voyage de 6 vers 4
# On voyage de 7 vers 2
# On voyage de 8 vers 6
# On voyage de 9 vers 3
# On voyage de 10 vers 8
# distance total parcouru 388.0
# 3.012,0.293,41,0.471,172,0,0.101
# Optimal solution found!
# On voyage de 1 vers 7
# On voyage de 2 vers 9
# On voyage de 3 vers 6
# On voyage de 4 vers 1
# On voyage de 5 vers 2
# On voyage de 6 vers 5
# On voyage de 7 vers 10
# On voyage de 8 vers 4
# On voyage de 9 vers 8
# On voyage de 10 vers 3
# distance total parcouru 324.0
# 2.841,8.278,829,0.794,339,0,0.028
# Optimal solution found!
# On voyage de 1 vers 5
# On voyage de 2 vers 8
# On voyage de 3 vers 7
# On voyage de 4 vers 3
# On voyage de 5 vers 4
# On voyage de 6 vers 10
# On voyage de 7 vers 2
# On voyage de 8 vers 6
# On voyage de 9 vers 1
# On voyage de 10 vers 9
# distance total parcouru 336.0
# 2.806,1.013,143,0.475,222,0,0.012
# Optimal solution found!
# On voyage de 1 vers 5
# On voyage de 2 vers 3
# On voyage de 3 vers 6
# On voyage de 4 vers 1
# On voyage de 5 vers 2
# On voyage de 6 vers 9
# On voyage de 7 vers 4
# On voyage de 8 vers 10
# On voyage de 9 vers 8
# On voyage de 10 vers 7
# distance total parcouru 402.0
# 2.509,2.073,286,1.646,618,0,0.015
# Optimal solution found!
# On voyage de 1 vers 3
# On voyage de 2 vers 4
# On voyage de 3 vers 9
# On voyage de 4 vers 8
# On voyage de 5 vers 6
# On voyage de 6 vers 1
# On voyage de 7 vers 2
# On voyage de 8 vers 10
# On voyage de 9 vers 7
# On voyage de 10 vers 5
# distance total parcouru 400.0
# 2.352,0.767,87,1.161,372,0.001,0.038
# Optimal solution found!
# On voyage de 1 vers 5
# On voyage de 2 vers 7
# On voyage de 3 vers 4
# On voyage de 4 vers 8
# On voyage de 5 vers 9
# On voyage de 6 vers 3
# On voyage de 7 vers 6
# On voyage de 8 vers 10
# On voyage de 9 vers 2
# On voyage de 10 vers 1
# distance total parcouru 302.0
# 2.075,0.032,5,0.247,77,0.001,0.032
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 6
# On voyage de 3 vers 1
# On voyage de 4 vers 3
# On voyage de 5 vers 4
# On voyage de 6 vers 9
# On voyage de 7 vers 2
# On voyage de 8 vers 10
# On voyage de 9 vers 5
# On voyage de 10 vers 7
# distance total parcouru 364.0
# 1.788,1.086,153,0.325,123,0,0.122
# Optimal solution found!
# On voyage de 1 vers 7
# On voyage de 2 vers 3
# On voyage de 3 vers 10
# On voyage de 4 vers 1
# On voyage de 5 vers 6
# On voyage de 6 vers 8
# On voyage de 7 vers 2
# On voyage de 8 vers 4
# On voyage de 9 vers 5
# On voyage de 10 vers 9
# distance total parcouru 310.0
# 1.455,0.435,78,2.927,1721,0,0.219
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 1
# On voyage de 3 vers 7
# On voyage de 4 vers 3
# On voyage de 5 vers 9
# On voyage de 6 vers 2
# On voyage de 7 vers 10
# On voyage de 8 vers 5
# On voyage de 9 vers 4
# On voyage de 10 vers 6
# distance total parcouru 386.0
# 1.395,2.358,321,1.758,1006,0,0.075
# Optimal solution found!
# On voyage de 1 vers 5
# On voyage de 2 vers 4
# On voyage de 3 vers 10
# On voyage de 4 vers 8
# On voyage de 5 vers 9
# On voyage de 6 vers 3
# On voyage de 7 vers 1
# On voyage de 8 vers 7
# On voyage de 9 vers 6
# On voyage de 10 vers 2
# distance total parcouru 322.0
# 5.09,36.323,1548,2.098,847,0,0.061
# Optimal solution found!
# On voyage de 1 vers 3
# On voyage de 2 vers 9
# On voyage de 3 vers 7
# On voyage de 4 vers 10
# On voyage de 5 vers 8
# On voyage de 6 vers 1
# On voyage de 7 vers 4
# On voyage de 8 vers 2
# On voyage de 9 vers 6
# On voyage de 10 vers 5
# distance total parcouru 334.0
# 1.676,0.065,3,0.254,47,0.001,0.034
# Optimal solution found!
# On voyage de 1 vers 3
# On voyage de 2 vers 8
# On voyage de 3 vers 10
# On voyage de 4 vers 6
# On voyage de 5 vers 4
# On voyage de 6 vers 1
# On voyage de 7 vers 2
# On voyage de 8 vers 5
# On voyage de 9 vers 7
# On voyage de 10 vers 9
# distance total parcouru 322.0
# 2.619,1.974,303,0.816,405,0,0.019
# Optimal solution found!
# On voyage de 1 vers 3
# On voyage de 2 vers 5
# On voyage de 3 vers 8
# On voyage de 4 vers 2
# On voyage de 5 vers 9
# On voyage de 6 vers 10
# On voyage de 7 vers 1
# On voyage de 8 vers 6
# On voyage de 9 vers 7
# On voyage de 10 vers 4
# distance total parcouru 352.0
# 2.036,0.031,3,0.077,15,0,0.013
# Optimal solution found!
# On voyage de 1 vers 7
# On voyage de 2 vers 4
# On voyage de 3 vers 8
# On voyage de 4 vers 5
# On voyage de 5 vers 3
# On voyage de 6 vers 10
# On voyage de 7 vers 6
# On voyage de 8 vers 9
# On voyage de 9 vers 1
# On voyage de 10 vers 2
# distance total parcouru 432.0
# 3.557,0.579,90,1.206,636,0,0.02
# Optimal solution found!
# On voyage de 1 vers 6
# On voyage de 2 vers 9
# On voyage de 3 vers 4
# On voyage de 4 vers 5
# On voyage de 5 vers 10
# On voyage de 6 vers 7
# On voyage de 7 vers 8
# On voyage de 8 vers 3
# On voyage de 9 vers 1
# On voyage de 10 vers 2
# distance total parcouru 336.0
# 2.855,0.732,98,1.723,1069,0,0.09
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 1
# On voyage de 3 vers 2
# On voyage de 4 vers 8
# On voyage de 5 vers 3
# On voyage de 6 vers 9
# On voyage de 7 vers 4
# On voyage de 8 vers 5
# On voyage de 9 vers 7
# On voyage de 10 vers 6
# distance total parcouru 356.0
# 3.057,7.39,806,2.243,1290,0,0.067
# Optimal solution found!
# On voyage de 1 vers 6
# On voyage de 2 vers 8
# On voyage de 3 vers 2
# On voyage de 4 vers 3
# On voyage de 5 vers 10
# On voyage de 6 vers 9
# On voyage de 7 vers 5
# On voyage de 8 vers 7
# On voyage de 9 vers 4
# On voyage de 10 vers 1
# distance total parcouru 400.0
# 3.705,15.457,1330,2.38,1117,0,0.03
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 5
# On voyage de 3 vers 10
# On voyage de 4 vers 2
# On voyage de 5 vers 7
# On voyage de 6 vers 4
# On voyage de 7 vers 9
# On voyage de 8 vers 6
# On voyage de 9 vers 3
# On voyage de 10 vers 1
# distance total parcouru 428.0
# 6.922,0.332,26,0.99,91,0,0.062
# Optimal solution found!
# On voyage de 1 vers 9
# On voyage de 2 vers 10
# On voyage de 3 vers 8
# On voyage de 4 vers 7
# On voyage de 5 vers 6
# On voyage de 6 vers 2
# On voyage de 7 vers 1
# On voyage de 8 vers 4
# On voyage de 9 vers 5
# On voyage de 10 vers 3
# distance total parcouru 348.0
# 5.926,6.102,556,1.781,558,0.001,0.049
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 8
# On voyage de 3 vers 5
# On voyage de 4 vers 7
# On voyage de 5 vers 1
# On voyage de 6 vers 9
# On voyage de 7 vers 6
# On voyage de 8 vers 3
# On voyage de 9 vers 2
# On voyage de 10 vers 4
# distance total parcouru 294.0
# 3.183,0.26,36,0.195,54,0,0.011
# Optimal solution found!
# On voyage de 1 vers 4
# On voyage de 2 vers 7
# On voyage de 3 vers 10
# On voyage de 4 vers 8
# On voyage de 5 vers 9
# On voyage de 6 vers 3
# On voyage de 7 vers 1
# On voyage de 8 vers 6
# On voyage de 9 vers 2
# On voyage de 10 vers 5
# distance total parcouru 408.0
# 4.933,3.621,331,0.518,169,0,0.021
# Optimal solution found!
# On voyage de 1 vers 8
# On voyage de 2 vers 10
# On voyage de 3 vers 1
# On voyage de 4 vers 5
# On voyage de 5 vers 9
# On voyage de 6 vers 7
# On voyage de 7 vers 4
# On voyage de 8 vers 6
# On voyage de 9 vers 2
# On voyage de 10 vers 3
# distance total parcouru 392.0
# 1.846,1.154,177,2.031,1086,0,0.14
# Optimal solution found!
# On voyage de 1 vers 7
# On voyage de 2 vers 8
# On voyage de 3 vers 4
# On voyage de 4 vers 6
# On voyage de 5 vers 2
# On voyage de 6 vers 1
# On voyage de 7 vers 5
# On voyage de 8 vers 10
# On voyage de 9 vers 3
# On voyage de 10 vers 9
# distance total parcouru 284.0
# 2.143,1.56,234,7.352,3766,0,0.119
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 4
# On voyage de 3 vers 7
# On voyage de 4 vers 9
# On voyage de 5 vers 1
# On voyage de 6 vers 5
# On voyage de 7 vers 2
# On voyage de 8 vers 6
# On voyage de 9 vers 8
# On voyage de 10 vers 3
# distance total parcouru 342.0
# 2.513,8.377,924,4.107,2150,0.001,0.16
# Optimal solution found!
# On voyage de 1 vers 10
# On voyage de 2 vers 5
# On voyage de 3 vers 6
# On voyage de 4 vers 8
# On voyage de 5 vers 7
# On voyage de 6 vers 4
# On voyage de 7 vers 9
# On voyage de 8 vers 1
# On voyage de 9 vers 3
# On voyage de 10 vers 2
# distance total parcouru 346.0
# 1.901,15.951,1468,3.533,1966,0,0.119
# Optimal solution found!
# On voyage de 1 vers 3
# On voyage de 2 vers 5
# On voyage de 3 vers 7
# On voyage de 4 vers 10
# On voyage de 5 vers 6
# On voyage de 6 vers 1
# On voyage de 7 vers 4
# On voyage de 8 vers 2
# On voyage de 9 vers 8
# On voyage de 10 vers 9
# distance total parcouru 342.0
# 3.68,13.171,1193,2.466,994,0,0.065
